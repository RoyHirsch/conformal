# %%
import os
import sys
import pandas as pd
import numpy as np

data_root = '/home/royhirsch/datasets/chexpert'
images_root = os.path.join(data_root, 'CheXpert-v1.0')
train_images_root = os.path.join(images_root, 'train')
valid_images_root = os.path.join(images_root, 'valid')
train_labels_csv = os.path.join(images_root, 'train.csv')
valid_labels_csv = os.path.join(images_root, 'valid.csv')

# %%
train_csv = pd.read_csv(train_labels_csv)
print('There are {} samples, {:.2f}% without findings.'.format(len(train_csv), train_csv['No Finding'].sum() / len(train_csv['No Finding']) * 100.))
# Out:
# There are 223414 samples, 10.02% without findings.

# %%
train_csv.drop(train_csv[train_csv['No Finding'] == 1].index, inplace = True)

# %%
print('There are {} samples, {:.2f}% without findings.'.format(len(train_csv), train_csv['No Finding'].sum() / len(train_csv['No Finding']) * 100.))
# Out:
# There are 201033 samples, 0.00% without findings.

# %%
train_csv.head()
# Out:
#                                                 Path     Sex  Age  \
# 1  CheXpert-v1.0/train/patient00002/study2/view1_...  Female   87
# 2  CheXpert-v1.0/train/patient00002/study1/view1_...  Female   83
# 3  CheXpert-v1.0/train/patient00002/study1/view2_...  Female   83
# 4  CheXpert-v1.0/train/patient00003/study1/view1_...    Male   41
# 9  CheXpert-v1.0/train/patient00005/study2/view1_...    Male   33
#
#   Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# 1         Frontal    AP         NaN                         NaN          -1.0
# 2         Frontal    AP         NaN                         NaN           NaN
# 3         Lateral   NaN         NaN                         NaN           NaN
# 4         Frontal    AP         NaN                         NaN           NaN
# 9         Frontal    AP         NaN                         NaN           NaN
#
#    Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  Atelectasis  \
# ...
